# %%
# to make the .py script runnable
#!/usr/bin/env python

# %%
from sklearn import datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('ggplot')

# %%
import os

# %% [markdown]
# # 2.6 Basic Exploration and Sanity checks - Tasks

# %% [markdown]
# What follows are a number of tasks in which you will receive or create a dataset to play around with. The main points the allow you to get 'a feel' for the dataset, with functions you create yourself. This is an important and often overlooked part of data science. It allows for sanity checks, which should be done and redone throughout any data science project. A lot of mistakes can be avoided this way, by simple checking of every outcome 'makes sense' (e.g. realising a maximum age in a dataset is 684 years or predicting that a probability is negative). Not all  commands needed have been explained literally previously, so mess around with the build-in Pythin information.
#
# Solutions can be found at the bottom.

# %% [markdown]
# ## 2.6.1 Tasks

# %% [markdown]
# ### Task 7

# %% [markdown]
# Generate a Series of 150 ages from a normal distribution with a mean of 35 years, pick your own reasonable SD (sanity check!). Set every fifteenth value to missing. Find the new mean. Fill the missing data with (a) mean (b) median, and report the new means.

# %% [markdown]
# ### Task 8

# %% [markdown]
# - Define a function call 'Standardizing' which works on a series as:
#     - Find the mean and standard deviation of the series
#     - Subtract each value of the series with the mean
#     - Divide the result with the standard deviation
#     - Returns a series with the results
# - Test on a random Series
#     - ask the mean and standard deviation of the standardized series
# - Apply this function to each numerical column (int or float) of the Titanic Dataset
#     - Once by manually checking which columns are float or int
#     - Once by letting Python decide
#     - ask the mean and standard deviation of the standardized series
#
# Standardizing is a very important technique in statistics, more on this later!

# %% [markdown]
# ### Task 9

# %% [markdown]
# Create a function called DESCRIBE_X that takes as input a Series,
# and produces a series containing
#
# - `min, max, sum, mean, std, missings, nonmissings, skew, kurtosis`
# - `percentiles - as specified by the user`
#
# so, it looks like:
#
# `DESCRIBE_X(s_1, percentiles=[0.1, 0.3, 0.92, 0.99]`
#
# Then, apply this function to the 1)rows 2) columns of a random constructed 10 by 5 DataFrame.

# %% [markdown]
# ### Task 10

# %% [markdown]
# - Report the shape of the Titanic DataFrame and the data type of each column.
#
# - Subset the data to retain only the passengers that survived. Name this object 'survivors'
# - Within the 'survivors' find the summary statistics of the 'Age' and 'Fare' variables.
#
# - Subset the survivors data to retain only Female passengers.
# - Find out how many females over the age of 30 survived.
#
# - Are there any missing values in the Age columnof the survivors dataframe? Did this impact the previous question?
# - Make a copy of the survivors dataframe with the missing Age values replaced with the mean.
# - Report the new summary statistics on Age. What happened? Why?
# - Find out how now many females over the age of 30 survived now. What changed? Does this make sense? What does this say about the previous result? What if the mean age was 31?

# %% [markdown]
# ## 2.6.2 Solutions

# %% [markdown]
# ### Task 7

# %% [markdown]
# Generate a Series of 150 ages from a normal distribution with a mean of 35 years, pick your own reasonable SD (sanity check!). Set every fifteenth value to missing. Find the new mean. Fill the missing data with (a) mean (b) median, and report the new means.

# %%
np.random.normal(loc=35, scale=10, size=150)
# Out:
# array([24.62355142, 43.39084382, 51.53442754, 39.27990492, 46.25031052,
#        36.55860536, 51.05900622, 43.26816453, 27.02370782, 27.22050074,
#        22.7330337 , 30.82498427, 30.42975071, 41.01016633, 50.50534289,
#        29.05813542, 27.18291729, 38.76521132, 25.49994803, 32.29436138,
#        33.04259458, 26.16645159, 27.90664065,  8.84721504, 18.72995718,
#        37.47837415, 46.64799458, 26.02450145, 35.44683774, 31.77087852,
#        25.42632919, 34.52104785, 30.33780978, 35.21186946, 46.49049687,
#        31.706755  , 37.89219176, 32.14202097, 34.7208261 , 33.27436649,
#        32.58399086, 23.79113693, 35.52706186, 35.90391147, 36.08412022,
#        30.82549072,  4.84588616, 40.80410361, 29.64656493, 17.30094262,
#        37.72714226, 32.041067  , 12.95265927, 27.03290361, 31.33223595,
#        29.90606948, 44.70124638, 26.4228755 , 23.79256407,  9.21370252,
#        30.98292602, 53.66855738, 39.46814554, 28.35217001, 34.30214558,
#        25.68952774, 44.37634328, 32.77017685, 14.92531266, 49.91516315,
#        41.51696473, 36.17396818, 38.87742132, 31.23642682, 34.05621776,
#        18.01056587, 32.20740823, 43.03202769, 23.13325849, 44.87754677,
#        30.00006004, 35.02206015, 52.89474917, 43.00001905, 44.47639322,
#        41.64974703, 50.11467512, 53.00904532, 36.5386535 , 40.93834075,
#        30.29365151, 17.10568253, 33.20017468, 31.35341901, 43.96436922,
#        21.75718754, 45.7165213 , 54.63954958, 32.17311116, 54.62430928,
#        37.22967149, 36.20128444, 29.42009844, 35.90304522, 33.46547068,
#        42.74607032, 37.40770148, 43.3345684 , 63.54561102, 31.28886656,
#        38.48686586, 29.53868638, 32.79255232, 35.06102546, 34.34644828,
#        38.02287327, 38.23471462, 19.82020296, 39.23849203, 22.76638195,
#        31.10340388, 27.88509097, 36.71965796, 54.39796833, 35.0066952 ,
#        26.87267559, 33.32729734, 20.62549613, 34.86895702, 35.41926451,
#        45.66383494, 39.78536583, 55.35795778, 30.9600849 , 42.0156904 ,
#        38.63249672, 43.10059997, 22.48207068, 36.31542039, 29.73344632,
#        44.36265303, 50.09736362, 39.10798113, 23.76027235, 38.63658831,
#        46.99282242, 32.02284554, 20.82408066, 19.86156773, 30.97067906])

# %%
ages = pd.Series(np.random.normal(loc=35, scale=10, size=150))
ages
# Out:
# 0      23.295854
# 1      35.418675
# 2      30.783763
# 3      35.592637
# 4      31.441039
# 5      27.215629
# 6      40.098145
# 7      44.626544
# 8      41.342058
# 9      35.631908
# 10     33.334627
# 11     42.264236
# 12     32.272869
# 13     43.294791
# 14     20.957006
# 15     38.504357
# 16     11.717584
# 17     43.883360
# 18     32.138184
# 19     42.436433
# 20     43.177389
# 21     49.568468
# 22     34.063409
# 23     31.107427
# 24     29.655758
# 25     40.267723
# 26     27.855405
# 27     27.096122
# 28     50.964104
# 29     30.610591
#          ...
# 120    25.805090
# 121    28.015848
# 122    43.023501
# 123    25.715934
# 124    48.490441
# 125    36.195236
# 126    27.624210
# 127    51.118389
# 128    32.964534
# 129    52.092552
# 130    34.957576
# 131    50.425775
# 132    43.139111
# 133    22.498836
# 134    56.145898
# 135    40.779030
# 136    23.330684
# 137    56.212364
# 138    28.068172
# 139    41.936312
# 140    34.657038
# 141    25.313992
# 142    33.434110
# 143    19.664907
# 144    26.040363
# 145    18.896453
# 146    22.527969
# 147    36.723952
# 148    36.072101
# 149    20.640842
# Length: 150, dtype: float64

# %%
ages.mean()
# Out:
# 35.14515073345027

# %%
print(ages)
# Out:
# 0      23.295854
# 1      35.418675
# 2      30.783763
# 3      35.592637
# 4      31.441039
# 5      27.215629
# 6      40.098145
# 7      44.626544
# 8      41.342058
# 9      35.631908
# 10     33.334627
# 11     42.264236
# 12     32.272869
# 13     43.294791
# 14     20.957006
# 15     38.504357
# 16     11.717584
# 17     43.883360
# 18     32.138184
# 19     42.436433
# 20     43.177389
# 21     49.568468
# 22     34.063409
# 23     31.107427
# 24     29.655758
# 25     40.267723
# 26     27.855405
# 27     27.096122
# 28     50.964104
# 29     30.610591
#          ...
# 120    25.805090
# 121    28.015848
# 122    43.023501
# 123    25.715934
# 124    48.490441
# 125    36.195236
# 126    27.624210
# 127    51.118389
# 128    32.964534
# 129    52.092552
# 130    34.957576
# 131    50.425775
# 132    43.139111
# 133    22.498836
# 134    56.145898
# 135    40.779030
# 136    23.330684
# 137    56.212364
# 138    28.068172
# 139    41.936312
# 140    34.657038
# 141    25.313992
# 142    33.434110
# 143    19.664907
# 144    26.040363
# 145    18.896453
# 146    22.527969
# 147    36.723952
# 148    36.072101
# 149    20.640842
# Length: 150, dtype: float64

# %%
ages.mean()
# Out:
# 35.14515073345027

# %%
for i in range(len(ages)):
    if (i + 1) % 15 == 0:
        ages[i] = None

# %%
ages.mean()
# Out:
# 35.2580046022811

# %%
ages[::15] = np.nan

# %%
print(ages)
# Out:
# 0            NaN
# 1      35.418675
# 2      30.783763
# 3      35.592637
# 4      31.441039
# 5      27.215629
# 6      40.098145
# 7      44.626544
# 8      41.342058
# 9      35.631908
# 10     33.334627
# 11     42.264236
# 12     32.272869
# 13     43.294791
# 14           NaN
# 15           NaN
# 16     11.717584
# 17     43.883360
# 18     32.138184
# 19     42.436433
# 20     43.177389
# 21     49.568468
# 22     34.063409
# 23     31.107427
# 24     29.655758
# 25     40.267723
# 26     27.855405
# 27     27.096122
# 28     50.964104
# 29           NaN
#          ...
# 120          NaN
# 121    28.015848
# 122    43.023501
# 123    25.715934
# 124    48.490441
# 125    36.195236
# 126    27.624210
# 127    51.118389
# 128    32.964534
# 129    52.092552
# 130    34.957576
# 131    50.425775
# 132    43.139111
# 133    22.498836
# 134          NaN
# 135          NaN
# 136    23.330684
# 137    56.212364
# 138    28.068172
# 139    41.936312
# 140    34.657038
# 141    25.313992
# 142    33.434110
# 143    19.664907
# 144    26.040363
# 145    18.896453
# 146    22.527969
# 147    36.723952
# 148    36.072101
# 149          NaN
# Length: 150, dtype: float64

# %%
ages.mean()
# Out:
# 35.30663390015777

# %%
ages.median()
# Out:
# 35.43341609541869

# %%
ages.fillna(ages.mean()).mean()
# Out:
# 35.30663390015777

# %%
ages.fillna(ages.median()).mean()
# Out:
# 35.32353819285923

# %% [markdown]
# ### Task 8

# %% [markdown]
# - Define a function call 'Standardizing' which works on a series as:
#     - Find the mean and standard deviation of the series
#     - Subtract each value of the series with the mean
#     - Divide the result with the standard deviation
#     - Returns a series with the results
# - Test on a random Series
#     - ask the mean and standard deviation of the standardized series
# - Apply this function to each numerical column (int or float) of the Titanic Dataset
#     - Once by manually checking which columns are float or int
#     - Once by letting Python decide
#     - ask the mean and standard deviation of the standardized series
#
# Standardizing is a very important technique in statistics, more on this later!

# %%
def standardize_s(ser):
    STser = (ser-ser.mean())/ser.std()
    return STser

# %%
ser1=pd.Series([1,2,3.1,4,5,6,7.5])

# %%
ser1.mean()
# Out:
# 4.085714285714286

# %%
ser1.median()
# Out:
# 4.0

# %%
ser1.std()
# Out:
# 2.2733445049299585

# %%
standardize_s(ser1)
# Out:
# 0   -1.357346
# 1   -0.917465
# 2   -0.433597
# 3   -0.037704
# 4    0.402176
# 5    0.842057
# 6    1.501878
# dtype: float64

# %%
standardize_s(ser1).mean()
# Out:
# -3.1720657846433045e-16

# %%
standardize_s(ser1).std()
# Out:
# 1.0

# %%
df_titanic = pd.read_csv('data/titanic.csv')
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
standardize_s(df_titanic.PassengerId) #similar for survived, Pclass, age, SinSp, parch and fare
# Out:
# 0     -1.729137
# 1     -1.725251
# 2     -1.721365
# 3     -1.717480
# 4     -1.713594
# 5     -1.709708
# 6     -1.705823
# 7     -1.701937
# 8     -1.698051
# 9     -1.694165
# 10    -1.690280
# 11    -1.686394
# 12    -1.682508
# 13    -1.678623
# 14    -1.674737
# 15    -1.670851
# 16    -1.666966
# 17    -1.663080
# 18    -1.659194
# 19    -1.655308
# 20    -1.651423
# 21    -1.647537
# 22    -1.643651
# 23    -1.639766
# 24    -1.635880
# 25    -1.631994
# 26    -1.628109
# 27    -1.624223
# 28    -1.620337
# 29    -1.616451
#          ...
# 861    1.616451
# 862    1.620337
# 863    1.624223
# 864    1.628109
# 865    1.631994
# 866    1.635880
# 867    1.639766
# 868    1.643651
# 869    1.647537
# 870    1.651423
# 871    1.655308
# 872    1.659194
# 873    1.663080
# 874    1.666966
# 875    1.670851
# 876    1.674737
# 877    1.678623
# 878    1.682508
# 879    1.686394
# 880    1.690280
# 881    1.694165
# 882    1.698051
# 883    1.701937
# 884    1.705823
# 885    1.709708
# 886    1.713594
# 887    1.717480
# 888    1.721365
# 889    1.725251
# 890    1.729137
# Name: PassengerId, Length: 891, dtype: float64

# %%
df_titanic.select_dtypes(include=['float64','int64'])
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare
# 0              1         0       3  22.0      1      0    7.2500
# 1              2         1       1  38.0      1      0   71.2833
# 2              3         1       3  26.0      0      0    7.9250
# 3              4         1       1  35.0      1      0   53.1000
# 4              5         0       3  35.0      0      0    8.0500
# 5              6         0       3   NaN      0      0    8.4583
# 6              7         0       1  54.0      0      0   51.8625
# 7              8         0       3   2.0      3      1   21.0750
# 8              9         1       3  27.0      0      2   11.1333
# 9             10         1       2  14.0      1      0   30.0708
# 10            11         1       3   4.0      1      1   16.7000
# 11            12         1       1  58.0      0      0   26.5500
# 12            13         0       3  20.0      0      0    8.0500
# 13            14         0       3  39.0      1      5   31.2750
# 14            15         0       3  14.0      0      0    7.8542
# 15            16         1       2  55.0      0      0   16.0000
# 16            17         0       3   2.0      4      1   29.1250
# 17            18         1       2   NaN      0      0   13.0000
# 18            19         0       3  31.0      1      0   18.0000
# 19            20         1       3   NaN      0      0    7.2250
# 20            21         0       2  35.0      0      0   26.0000
# 21            22         1       2  34.0      0      0   13.0000
# 22            23         1       3  15.0      0      0    8.0292
# 23            24         1       1  28.0      0      0   35.5000
# 24            25         0       3   8.0      3      1   21.0750
# 25            26         1       3  38.0      1      5   31.3875
# 26            27         0       3   NaN      0      0    7.2250
# 27            28         0       1  19.0      3      2  263.0000
# 28            29         1       3   NaN      0      0    7.8792
# 29            30         0       3   NaN      0      0    7.8958
# ..           ...       ...     ...   ...    ...    ...       ...
# 861          862         0       2  21.0      1      0   11.5000
# 862          863         1       1  48.0      0      0   25.9292
# 863          864         0       3   NaN      8      2   69.5500
# 864          865         0       2  24.0      0      0   13.0000
# 865          866         1       2  42.0      0      0   13.0000
# 866          867         1       2  27.0      1      0   13.8583
# 867          868         0       1  31.0      0      0   50.4958
# 868          869         0       3   NaN      0      0    9.5000
# 869          870         1       3   4.0      1      1   11.1333
# 870          871         0       3  26.0      0      0    7.8958
# 871          872         1       1  47.0      1      1   52.5542
# 872          873         0       1  33.0      0      0    5.0000
# 873          874         0       3  47.0      0      0    9.0000
# 874          875         1       2  28.0      1      0   24.0000
# 875          876         1       3  15.0      0      0    7.2250
# 876          877         0       3  20.0      0      0    9.8458
# 877          878         0       3  19.0      0      0    7.8958
# 878          879         0       3   NaN      0      0    7.8958
# 879          880         1       1  56.0      0      1   83.1583
# 880          881         1       2  25.0      0      1   26.0000
# 881          882         0       3  33.0      0      0    7.8958
# 882          883         0       3  22.0      0      0   10.5167
# 883          884         0       2  28.0      0      0   10.5000
# 884          885         0       3  25.0      0      0    7.0500
# 885          886         0       3  39.0      0      5   29.1250
# 886          887         0       2  27.0      0      0   13.0000
# 887          888         1       1  19.0      0      0   30.0000
# 888          889         0       3   NaN      1      2   23.4500
# 889          890         1       1  26.0      0      0   30.0000
# 890          891         0       3  32.0      0      0    7.7500
#
# [891 rows x 7 columns]

# %%
df_titanic.select_dtypes(include=['float64','int64']).apply(lambda x : standardize_s(x))
# Out:
#      PassengerId  Survived    Pclass       Age     SibSp     Parch      Fare
# 0      -1.729137 -0.788829  0.826913 -0.530005  0.432550 -0.473408 -0.502163
# 1      -1.725251  1.266279 -1.565228  0.571430  0.432550 -0.473408  0.786404
# 2      -1.721365  1.266279  0.826913 -0.254646 -0.474279 -0.473408 -0.488580
# 3      -1.717480  1.266279 -1.565228  0.364911  0.432550 -0.473408  0.420494
# 4      -1.713594 -0.788829  0.826913  0.364911 -0.474279 -0.473408 -0.486064
# 5      -1.709708 -0.788829  0.826913       NaN -0.474279 -0.473408 -0.477848
# 6      -1.705823 -0.788829 -1.565228  1.672866 -0.474279 -0.473408  0.395591
# 7      -1.701937 -0.788829  0.826913 -1.906799  2.246209  0.767199 -0.223957
# 8      -1.698051  1.266279  0.826913 -0.185807 -0.474279  2.007806 -0.424018
# 9      -1.694165  1.266279 -0.369158 -1.080723  0.432550 -0.473408 -0.042931
# 10     -1.690280  1.266279  0.826913 -1.769120  0.432550  0.767199 -0.311997
# 11     -1.686394  1.266279 -1.565228  1.948225 -0.474279 -0.473408 -0.113782
# 12     -1.682508 -0.788829  0.826913 -0.667685 -0.474279 -0.473408 -0.486064
# 13     -1.678623 -0.788829  0.826913  0.640270  0.432550  5.729626 -0.018699
# 14     -1.674737 -0.788829  0.826913 -1.080723 -0.474279 -0.473408 -0.490005
# 15     -1.670851  1.266279 -0.369158  1.741706 -0.474279 -0.473408 -0.326084
# 16     -1.666966 -0.788829  0.826913 -1.906799  3.153038  0.767199 -0.061964
# 17     -1.663080  1.266279 -0.369158       NaN -0.474279 -0.473408 -0.386454
# 18     -1.659194 -0.788829  0.826913  0.089552  0.432550 -0.473408 -0.285837
# 19     -1.655308  1.266279  0.826913       NaN -0.474279 -0.473408 -0.502666
# 20     -1.651423 -0.788829 -0.369158  0.364911 -0.474279 -0.473408 -0.124850
# 21     -1.647537  1.266279 -0.369158  0.296072 -0.474279 -0.473408 -0.386454
# 22     -1.643651  1.266279  0.826913 -1.011883 -0.474279 -0.473408 -0.486483
# 23     -1.639766  1.266279 -1.565228 -0.116967 -0.474279 -0.473408  0.066322
# 24     -1.635880 -0.788829  0.826913 -1.493761  2.246209  0.767199 -0.223957
# 25     -1.631994  1.266279  0.826913  0.571430  0.432550  5.729626 -0.016435
# 26     -1.628109 -0.788829  0.826913       NaN -0.474279 -0.473408 -0.502666
# 27     -1.624223 -0.788829 -1.565228 -0.736524  2.246209  2.007806  4.644393
# 28     -1.620337  1.266279  0.826913       NaN -0.474279 -0.473408 -0.489502
# 29     -1.616451 -0.788829  0.826913       NaN -0.474279 -0.473408 -0.489167
# ..           ...       ...       ...       ...       ...       ...       ...
# 861     1.616451 -0.788829 -0.369158 -0.598845  0.432550 -0.473408 -0.416639
# 862     1.620337  1.266279 -1.565228  1.259828 -0.474279 -0.473408 -0.126274
# 863     1.624223 -0.788829  0.826913       NaN  6.780355  2.007806  0.751524
# 864     1.628109 -0.788829 -0.369158 -0.392326 -0.474279 -0.473408 -0.386454
# 865     1.631994  1.266279 -0.369158  0.846789 -0.474279 -0.473408 -0.386454
# 866     1.635880  1.266279 -0.369158 -0.185807  0.432550 -0.473408 -0.369182
# 867     1.639766 -0.788829 -1.565228  0.089552 -0.474279 -0.473408  0.368089
# 868     1.643651 -0.788829  0.826913       NaN -0.474279 -0.473408 -0.456886
# 869     1.647537  1.266279  0.826913 -1.769120  0.432550  0.767199 -0.424018
# 870     1.651423 -0.788829  0.826913 -0.254646 -0.474279 -0.473408 -0.489167
# 871     1.655308  1.266279 -1.565228  1.190988  0.432550  0.767199  0.409511
# 872     1.659194 -0.788829 -1.565228  0.227232 -0.474279 -0.473408 -0.547441
# 873     1.663080 -0.788829  0.826913  1.190988 -0.474279 -0.473408 -0.466947
# 874     1.666966  1.266279 -0.369158 -0.116967  0.432550 -0.473408 -0.165096
# 875     1.670851  1.266279  0.826913 -1.011883 -0.474279 -0.473408 -0.502666
# 876     1.674737 -0.788829  0.826913 -0.667685 -0.474279 -0.473408 -0.449927
# 877     1.678623 -0.788829  0.826913 -0.736524 -0.474279 -0.473408 -0.489167
# 878     1.682508 -0.788829  0.826913       NaN -0.474279 -0.473408 -0.489167
# 879     1.686394  1.266279 -1.565228  1.810545 -0.474279  0.767199  1.025369
# 880     1.690280  1.266279 -0.369158 -0.323486 -0.474279  0.767199 -0.124850
# 881     1.694165 -0.788829  0.826913  0.227232 -0.474279 -0.473408 -0.489167
# 882     1.698051 -0.788829  0.826913 -0.530005 -0.474279 -0.473408 -0.436426
# 883     1.701937 -0.788829 -0.369158 -0.116967 -0.474279 -0.473408 -0.436762
# 884     1.705823 -0.788829  0.826913 -0.323486 -0.474279 -0.473408 -0.506188
# 885     1.709708 -0.788829  0.826913  0.640270 -0.474279  5.729626 -0.061964
# 886     1.713594 -0.788829 -0.369158 -0.185807 -0.474279 -0.473408 -0.386454
# 887     1.717480  1.266279 -1.565228 -0.736524 -0.474279 -0.473408 -0.044356
# 888     1.721365 -0.788829  0.826913       NaN  0.432550  2.007806 -0.176164
# 889     1.725251  1.266279 -1.565228 -0.254646 -0.474279 -0.473408 -0.044356
# 890     1.729137 -0.788829  0.826913  0.158392 -0.474279 -0.473408 -0.492101
#
# [891 rows x 7 columns]

# %%
df_titanic.select_dtypes(include=['float64','int64']).apply(lambda x : standardize_s(x)).mean() #.round()
# Out:
# PassengerId   -2.317637e-17
# Survived      -6.180366e-17
# Pclass        -2.360003e-16
# Age            2.232497e-16
# SibSp         -2.217954e-16
# Parch          2.753752e-17
# Fare           9.968332e-18
# dtype: float64

# %%
df_titanic.select_dtypes(include=['float64','int64']).apply(lambda x : standardize_s(x)).std()
# Out:
# PassengerId    1.0
# Survived       1.0
# Pclass         1.0
# Age            1.0
# SibSp          1.0
# Parch          1.0
# Fare           1.0
# dtype: float64

# %% [markdown]
# ### Task 9

# %% [markdown]
# Create a function called DESCRIBE_X that takes as input a Series,
# and produces a series containing
#
# - `min, max, sum, mean, std, missings, nonmissings, skew, kurtosis`
# - `percentiles - as specified by the user`
#
# so, it looks like:
#
# `DESCRIBE_X(s_1, percentiles=[0.1, 0.3, 0.92, 0.99]`
#
# Then, apply this function to the 1)rows 2) columns of a random constructed 10 by 5 DataFrame.

# %%
def DESCRIBE_X(s=pd.Series(), perc=[]):
    """
    
    """
    s1 = pd.Series({'MIN': s.min(), 
                 'MAX': s.max(), 
                 'SUM': s.sum(), 
                 'MEAN': s.mean(), 
                 'MEDIAN': s.median(), 
                 'MISSINGS': s.isnull().sum(), 
                 'NONMISSINGS': s.notnull().sum(),
                 'SKEW': s.skew(), 
                 'KURT': s.kurtosis()})
    s2 = s.quantile(perc)
    return pd.concat([s1, s2])

# %%
DESCRIBE_X(s=pd.Series(np.random.random(100)), perc=[0.5, 0.25, 0.75])
# Out:
# MIN              0.013501
# MAX              0.985483
# SUM             50.848565
# MEAN             0.508486
# MEDIAN           0.513066
# MISSINGS         0.000000
# NONMISSINGS    100.000000
# SKEW            -0.008368
# KURT            -1.260994
# 0.5              0.513066
# 0.25             0.264112
# 0.75             0.746390
# dtype: float64

# %%
ser1.describe()
# Out:
# count    7.000000
# mean     4.085714
# std      2.273345
# min      1.000000
# 25%      2.550000
# 50%      4.000000
# 75%      5.500000
# max      7.500000
# dtype: float64

# %%
df_1 = pd.DataFrame(np.random.randn(50).reshape(10, 5), columns=['Col_' + str(i) for i in range(5)])
df_1
# Out:
#       Col_0     Col_1     Col_2     Col_3     Col_4
# 0 -0.059339  1.119410  2.496873 -1.527336 -1.510875
# 1 -1.270804  0.265423  0.361511 -0.158218  1.864205
# 2  0.943151 -2.975639  1.154291 -0.463925  0.013872
# 3 -0.530674  0.970509 -1.569220  0.489549 -0.001683
# 4  0.259932  1.251442 -0.674431  0.213347  1.245668
# 5 -0.205076  0.089472 -1.170028  0.812149 -0.738358
# 6 -0.462805  0.619822 -0.869817  0.955217  1.236143
# 7 -1.731952  0.669719 -0.257979 -0.053682  0.003356
# 8  2.027398 -1.228313 -0.259053 -1.605586 -0.459099
# 9  0.803376  1.145691 -0.760091  0.264123 -0.092886

# %%
df_1.apply(lambda c: DESCRIBE_X(s=c, perc=[0.1, 0.2, 0.8, 0.9]))
# Out:
#                  Col_0      Col_1      Col_2      Col_3      Col_4
# MIN          -1.731952  -2.975639  -1.569220  -1.605586  -1.510875
# MAX           2.027398   1.251442   2.496873   0.955217   1.864205
# SUM          -0.226793   1.927535  -1.547945  -1.074364   1.560343
# MEAN         -0.022679   0.192753  -0.154794  -0.107436   0.156034
# MEDIAN       -0.132207   0.644770  -0.466742   0.079832   0.000836
# MISSINGS      0.000000   0.000000   0.000000   0.000000   0.000000
# NONMISSINGS  10.000000  10.000000  10.000000  10.000000  10.000000
# SKEW          0.308180  -1.830549   1.282160  -0.815121   0.253086
# KURT          0.165551   3.149365   1.532771  -0.234328  -0.344368
# 0.1          -1.316919  -1.403046  -1.209947  -1.535161  -0.815610
# 0.2          -0.678700  -0.174085  -0.929860  -0.676608  -0.514951
# 0.8           0.831331   1.124666   0.520067   0.554069   1.238048
# 0.9           1.051575   1.156266   1.288549   0.826456   1.307521

# %%
df_1.apply(lambda c: DESCRIBE_X(s=c, perc=[0.1, 0.2, 0.8, 0.9]), axis=1)
# Out:
#         MIN       MAX       SUM      MEAN    MEDIAN  MISSINGS  NONMISSINGS  \
# 0 -1.527336  2.496873  0.518732  0.103746 -0.059339       0.0          5.0
# 1 -1.270804  1.864205  1.062116  0.212423  0.265423       0.0          5.0
# 2 -2.975639  1.154291 -1.328251 -0.265650  0.013872       0.0          5.0
# 3 -1.569220  0.970509 -0.641519 -0.128304 -0.001683       0.0          5.0
# 4 -0.674431  1.251442  2.295957  0.459191  0.259932       0.0          5.0
# 5 -1.170028  0.812149 -1.211841 -0.242368 -0.205076       0.0          5.0
# 6 -0.869817  1.236143  1.478560  0.295712  0.619822       0.0          5.0
# 7 -1.731952  0.669719 -1.370539 -0.274108 -0.053682       0.0          5.0
# 8 -1.605586  2.027398 -1.524654 -0.304931 -0.459099       0.0          5.0
# 9 -0.760091  1.145691  1.360213  0.272043  0.264123       0.0          5.0
#
#        SKEW      KURT       0.1       0.2       0.8       0.9
# 0  0.493928 -1.427481 -1.520752 -1.514168  1.394903  1.945888
# 1  0.347141  1.494811 -0.825770 -0.380735  0.662050  1.263127
# 2 -1.405864  2.052301 -1.970954 -0.966268  0.985379  1.069835
# 3 -0.660179  0.043811 -1.153802 -0.738383  0.585741  0.778125
# 4 -0.387203 -0.972035 -0.319320  0.035791  1.246822  1.249132
# 5  0.270757 -0.449203 -0.997360 -0.824692  0.234007  0.523078
# 6 -0.469668 -2.398034 -0.707012 -0.544207  1.011402  1.123773
# 7 -1.332025  2.775617 -1.142363 -0.552773  0.136628  0.403174
# 8  1.425705  2.343074 -1.454677 -1.303768  0.198237  1.112818
# 9 -0.328504 -0.792476 -0.493209 -0.226327  0.871839  1.008765

# %% [markdown]
# ### Task 10

# %% [markdown]
# - Report the shape of the Titanic DataFrame and the data type of each column.
#
# - Subset the data to retain only the passengers that survived. Name this object 'survivors'
# - Within the 'survivors' find the summary statistics of the 'Age' and 'Fare' variables.
#
# - Subset the survivors data to retain only Female passengers.
# - Find out how many females over the age of 30 survived.
#
# - Are there any missing values in the Age columnof the survivors dataframe? Did this impact the previous question?
# - Make a copy of the survivors dataframe with the missing Age values replaced with the mean.
# - Report the new summary statistics on Age. What happened? Why?
# - Find out how now many females over the age of 30 survived now. What changed? Does this make sense? What does this say about the previous result? What if the mean age was 31?

# %%
df_titanic = pd.read_csv("data/titanic.csv")

# %%
df_titanic.sample(3)
# Out:
#      PassengerId  Survived  Pclass                         Name     Sex   Age  \
# 277          278         0       2  Parkes, Mr. Francis "Frank"    male   NaN
# 380          381         1       1        Bidois, Miss. Rosalie  female  42.0
# 120          121         0       2  Hickman, Mr. Stanley George    male  21.0
#
#      SibSp  Parch        Ticket     Fare Cabin Embarked
# 277      0      0        239853    0.000   NaN        S
# 380      0      0      PC 17757  227.525   NaN        C
# 120      2      0  S.O.C. 14879   73.500   NaN        S

# %%
df_titanic.shape
# Out:
# (891, 12)

# %%
survivors=df_titanic[df_titanic.Survived==True]

# %%
len(survivors)
# Out:
# 342

# %%
len(df_titanic)
# Out:
# 891

# %%
survivors['Age'].describe()
# Out:
# count    290.000000
# mean      28.343690
# std       14.950952
# min        0.420000
# 25%       19.000000
# 50%       28.000000
# 75%       36.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
survivors['Fare'].describe()
# Out:
# count    342.000000
# mean      48.395408
# std       66.596998
# min        0.000000
# 25%       12.475000
# 50%       26.000000
# 75%       57.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
female_survivors = survivors.loc[(survivors.Sex == 'female')]
female_survivors
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 19            20         1       3
# 22            23         1       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 56            57         1       2
# 58            59         1       2
# 61            62         1       1
# 66            67         1       2
# 68            69         1       3
# 79            80         1       3
# 82            83         1       3
# 84            85         1       2
# 85            86         1       3
# 88            89         1       1
# ..           ...       ...     ...
# 774          775         1       2
# 777          778         1       3
# 779          780         1       1
# 780          781         1       3
# 781          782         1       1
# 786          787         1       3
# 796          797         1       1
# 797          798         1       3
# 801          802         1       2
# 809          810         1       1
# 820          821         1       1
# 823          824         1       3
# 829          830         1       1
# 830          831         1       3
# 835          836         1       1
# 842          843         1       1
# 849          850         1       1
# 853          854         1       1
# 855          856         1       3
# 856          857         1       1
# 858          859         1       3
# 862          863         1       1
# 865          866         1       2
# 866          867         1       2
# 871          872         1       1
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 32                            Glynn, Miss. Mary Agatha  female   NaN      0
# 39                         Nicola-Yarred, Miss. Jamila  female  14.0      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 44                       Devaney, Miss. Margaret Delia  female  19.0      0
# 47                           O'Driscoll, Miss. Bridget  female   NaN      0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 53   Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female  29.0      1
# 56                                   Rugg, Miss. Emily  female  21.0      0
# 58                        West, Miss. Constance Mirium  female   5.0      1
# 61                                 Icard, Miss. Amelie  female  38.0      0
# 66                        Nye, Mrs. (Elizabeth Ramell)  female  29.0      0
# 68                     Andersson, Miss. Erna Alexandra  female  17.0      4
# 79                            Dowdell, Miss. Elizabeth  female  30.0      0
# 82                      McDermott, Miss. Brigdet Delia  female   NaN      0
# 84                                 Ilett, Miss. Bertha  female  17.0      0
# 85   Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...  female  33.0      3
# 88                          Fortune, Miss. Mabel Helen  female  23.0      3
# ..                                                 ...     ...   ...    ...
# 774              Hocking, Mrs. Elizabeth (Eliza Needs)  female  54.0      1
# 777                      Emanuel, Miss. Virginia Ethel  female   5.0      0
# 779  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  female  43.0      0
# 780                               Ayoub, Miss. Banoura  female  13.0      0
# 781          Dick, Mrs. Albert Adrian (Vera Gillespie)  female  17.0      1
# 786                          Sjoblom, Miss. Anna Sofia  female  18.0      0
# 796                        Leader, Dr. Alice (Farnham)  female  49.0      0
# 797                                   Osman, Mrs. Mara  female  31.0      0
# 801        Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.0      1
# 809     Chambers, Mrs. Norman Campbell (Bertha Griggs)  female  33.0      1
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female  52.0      1
# 823                                 Moor, Mrs. (Beila)  female  27.0      0
# 829          Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
# 830            Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0      1
# 835                        Compton, Miss. Sara Rebecca  female  39.0      1
# 842                            Serepeca, Miss. Augusta  female  30.0      0
# 849       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female   NaN      1
# 853                          Lines, Miss. Mary Conover  female  16.0      0
# 855                         Aks, Mrs. Sam (Leah Rosen)  female  18.0      0
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 858              Baclini, Mrs. Solomon (Latifa Qurban)  female  24.0      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch            Ticket      Fare        Cabin Embarked
# 1        0          PC 17599   71.2833          C85        C
# 2        0  STON/O2. 3101282    7.9250          NaN        S
# 3        0            113803   53.1000         C123        S
# 8        2            347742   11.1333          NaN        S
# 9        0            237736   30.0708          NaN        C
# 10       1           PP 9549   16.7000           G6        S
# 11       0            113783   26.5500         C103        S
# 15       0            248706   16.0000          NaN        S
# 19       0              2649    7.2250          NaN        C
# 22       0            330923    8.0292          NaN        Q
# 25       5            347077   31.3875          NaN        S
# 28       0            330959    7.8792          NaN        Q
# 31       0          PC 17569  146.5208          B78        C
# 32       0            335677    7.7500          NaN        Q
# 39       0              2651   11.2417          NaN        C
# 43       2     SC/Paris 2123   41.5792          NaN        C
# 44       0            330958    7.8792          NaN        Q
# 47       0             14311    7.7500          NaN        Q
# 52       0          PC 17572   76.7292          D33        C
# 53       0              2926   26.0000          NaN        S
# 56       0        C.A. 31026   10.5000          NaN        S
# 58       2        C.A. 34651   27.7500          NaN        S
# 61       0            113572   80.0000          B28      NaN
# 66       0        C.A. 29395   10.5000          F33        S
# 68       2           3101281    7.9250          NaN        S
# 79       0            364516   12.4750          NaN        S
# 82       0            330932    7.7875          NaN        Q
# 84       0        SO/C 14885   10.5000          NaN        S
# 85       0           3101278   15.8500          NaN        S
# 88       2             19950  263.0000  C23 C25 C27        S
# ..     ...               ...       ...          ...      ...
# 774      3             29105   23.0000          NaN        S
# 777      0            364516   12.4750          NaN        S
# 779      1             24160  211.3375           B3        S
# 780      0              2687    7.2292          NaN        C
# 781      0             17474   57.0000          B20        S
# 786      0           3101265    7.4958          NaN        S
# 796      0             17465   25.9292          D17        S
# 797      0            349244    8.6833          NaN        S
# 801      1        C.A. 31921   26.2500          NaN        S
# 809      0            113806   53.1000           E8        S
# 820      1             12749   93.5000          B69        S
# 823      1            392096   12.4750         E121        S
# 829      0            113572   80.0000          B28      NaN
# 830      0              2659   14.4542          NaN        C
# 835      1          PC 17756   83.1583          E49        C
# 842      0            113798   31.0000          NaN        C
# 849      0             17453   89.1042          C92        C
# 853      1          PC 17592   39.4000          D28        S
# 855      1            392091    9.3500          NaN        S
# 856      1             36928  164.8667          NaN        S
# 858      3              2666   19.2583          NaN        C
# 862      0             17466   25.9292          D17        S
# 865      0            236852   13.0000          NaN        S
# 866      0     SC/PARIS 2149   13.8583          NaN        C
# 871      1             11751   52.5542          D35        S
# 874      0         P/PP 3381   24.0000          NaN        C
# 875      0              2667    7.2250          NaN        C
# 879      1             11767   83.1583          C50        C
# 880      1            230433   26.0000          NaN        S
# 887      0            112053   30.0000          B42        S
#
# [233 rows x 12 columns]

# %%
len(survivors.loc[(survivors.Sex == 'female') & (survivors.Age > 30)].index)
# Out:
# 83

# %% [markdown]
# or

# %%
df_titanic.loc[(df_titanic.Sex == 'female') & (df_titanic.Age > 30), 'Survived'].sum()
# Out:
# 83

# %%
survivors['Age'].unique()
# Out:
# array([38.  , 26.  , 35.  , 27.  , 14.  ,  4.  , 58.  , 55.  ,   nan,
#        34.  , 15.  , 28.  ,  3.  , 19.  , 49.  , 29.  , 21.  ,  5.  ,
#        17.  , 32.  ,  0.83, 30.  , 33.  , 23.  , 32.5 , 12.  , 24.  ,
#        22.  , 16.  , 40.  ,  9.  ,  1.  , 45.  , 44.  , 18.  , 31.  ,
#         8.  , 37.  , 50.  , 25.  , 41.  , 63.  , 42.  ,  0.92, 36.  ,
#         2.  , 60.  , 39.  , 13.  , 52.  , 48.  ,  0.75, 54.  ,  7.  ,
#        62.  , 53.  , 20.  , 80.  , 56.  ,  6.  ,  0.67, 51.  , 43.  ,
#        11.  ,  0.42, 47.  ])

# %%
len(survivors['Age'].isnull())
# Out:
# 342

# %%
len(survivors['Age'].notnull())
# Out:
# 342

# %%
len(survivors['Age'])
# Out:
# 342

# %%
survivors['Age'].notnull().sum()
# Out:
# 290

# %%
survivors['Age'].isnull().sum()
# Out:
# 52

# %%
survivors_NoMisAge = survivors.copy()

# %%
survivors_NoMisAge['Age'].fillna(survivors['Age'].mean(), inplace=True)

# %%
len(survivors_NoMisAge['Age'])
# Out:
# 342

# %%
survivors_NoMisAge['Age'].isnull().sum()
# Out:
# 0

# %%
survivors['Age'].describe()
# Out:
# count    290.000000
# mean      28.343690
# std       14.950952
# min        0.420000
# 25%       19.000000
# 50%       28.000000
# 75%       36.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
survivors_NoMisAge['Age'].describe()
# Out:
# count    342.000000
# mean      28.343690
# std       13.763871
# min        0.420000
# 25%       21.000000
# 50%       28.343690
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
len(survivors_NoMisAge.loc[(df_titanic.Sex == 'female') & (survivors_NoMisAge.Age > 30)].index)
# Out:
# 83

# %%
df_titanic.loc[(df_titanic.Sex == 'female') & (df_titanic.Age > 30), 'Survived'].sum()
# Out:
# 83
